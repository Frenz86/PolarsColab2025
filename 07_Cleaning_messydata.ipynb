# %%
## Download wrapping for seaborn
# !wget https://frenzy86.s3.eu-west-2.amazonaws.com/python/plotlib.py
# Out:
# --2024-03-19 17:04:31--  https://frenzy86.s3.eu-west-2.amazonaws.com/python/plotlib.py
# Resolving frenzy86.s3.eu-west-2.amazonaws.com (frenzy86.s3.eu-west-2.amazonaws.com)... 52.95.150.82, 52.95.149.198, 52.95.149.166, ...
# Connecting to frenzy86.s3.eu-west-2.amazonaws.com (frenzy86.s3.eu-west-2.amazonaws.com)|52.95.150.82|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2796 (2.7K) [text/plain]
# Saving to: ‘plotlib.py’
#
# plotlib.py          100%[===================>]   2.73K  --.-KB/s    in 0s
#
# 2024-03-19 17:04:31 (122 MB/s) - ‘plotlib.py’ saved [2796/2796]

# %%
# !wget https://frenzy86.s3.eu-west-2.amazonaws.com/python/data/311-service-requests.csv
path = "311-service-requests.csv"

#path = "https://frenzy86.s3.eu-west-2.amazonaws.com/python/data/311-service-requests.csv"

# %%
import polars as pl

# %% [markdown]
# One of the main problems with messy data is: how do you know if it's messy or not?
#
# We're going to use the NYC 311 service request dataset again here, since it's big and a bit unwieldy. If we try to read it in polars, we immediately run into an error. Polars cannot infer the data type of the data in the csv file:

# %%
## fake, normal error
requests = pl.read_csv(path)
# Out:
# ---------------------------------------------------------------------------
# ComputeError                              Traceback (most recent call last)
# <ipython-input-22-62dbfa17fc6e> in <cell line: 2>()
#       1 ## fake, normal error
# ----> 2 requests = pl.read_csv(path)
#
# /usr/local/lib/python3.10/dist-packages/polars/utils/deprecation.py in wrapper(*args, **kwargs)
#      98                 old_name, new_name, kwargs, function.__name__, version
#      99             )
# --> 100             return function(*args, **kwargs)
#     101
#     102         wrapper.__signature__ = inspect.signature(function)  # type: ignore[attr-defined]
#
# /usr/local/lib/python3.10/dist-packages/polars/io/csv/functions.py in read_csv(source, has_header, columns, new_columns, separator, comment_prefix, quote_char, skip_rows, dtypes, schema, null_values, missing_utf8_is_empty_string, ignore_errors, try_parse_dates, n_threads, infer_schema_length, batch_size, n_rows, encoding, low_memory, rechunk, use_pyarrow, storage_options, skip_rows_after_header, row_count_name, row_count_offset, sample_size, eol_char, raise_if_empty, truncate_ragged_lines)
#     367         storage_options=storage_options,
#     368     ) as data:
# --> 369         df = pl.DataFrame._read_csv(
#     370             data,
#     371             has_header=has_header,
#
# /usr/local/lib/python3.10/dist-packages/polars/dataframe/frame.py in _read_csv(cls, source, has_header, columns, separator, comment_prefix, quote_char, skip_rows, dtypes, schema, null_values, missing_utf8_is_empty_string, ignore_errors, try_parse_dates, n_threads, infer_schema_length, batch_size, n_rows, encoding, low_memory, rechunk, skip_rows_after_header, row_count_name, row_count_offset, sample_size, eol_char, raise_if_empty, truncate_ragged_lines)
#     782         projection, columns = handle_projection_columns(columns)
#     783
# --> 784         self._df = PyDataFrame.read_csv(
#     785             source,
#     786             infer_schema_length,
#
# ComputeError: could not parse `N/A` as dtype `i64` at column 'Incident Zip' (column number 9)
#
# The current offset in the file is 3842181 bytes.
#
# You might want to try:
# - increasing `infer_schema_length` (e.g. `infer_schema_length=10000`),
# - specifying correct dtype with the `dtypes` argument
# - setting `ignore_errors` to `True`,
# - adding `N/A` to the `null_values` list.
#
# Original error: ```remaining bytes non-empty```

# %% [markdown]
# We can force polars to try harder to infer the data type by setting `infer_schema_length` to `None`. Looking at the schema below, I can see that `Incident Zip` was parsed as a `Utf8` (a string). That doesn't look right.

# %%
requests = pl.read_csv(path, infer_schema_length=None)

display(requests.head())
display(requests.schema)
# Out:
# shape: (5, 52)
# ┌────────────┬────────────┬───────────┬────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ Unique Key ┆ Created    ┆ Closed    ┆ Agency ┆ … ┆ Ferry     ┆ Latitude  ┆ Longitude ┆ Location  │
# │ ---        ┆ Date       ┆ Date      ┆ ---    ┆   ┆ Terminal  ┆ ---       ┆ ---       ┆ ---       │
# │ i64        ┆ ---        ┆ ---       ┆ str    ┆   ┆ Name      ┆ f64       ┆ f64       ┆ str       │
# │            ┆ str        ┆ str       ┆        ┆   ┆ ---       ┆           ┆           ┆           │
# │            ┆            ┆           ┆        ┆   ┆ str       ┆           ┆           ┆           │
# ╞════════════╪════════════╪═══════════╪════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 26589651   ┆ 10/31/2013 ┆ null      ┆ NYPD   ┆ … ┆ null      ┆ 40.708275 ┆ -73.79160 ┆ (40.70827 │
# │            ┆ 02:08:41   ┆           ┆        ┆   ┆           ┆           ┆ 4         ┆ 532593202 │
# │            ┆ AM         ┆           ┆        ┆   ┆           ┆           ┆           ┆ , -73.791 │
# │            ┆            ┆           ┆        ┆   ┆           ┆           ┆           ┆ 60395…    │
# │ 26593698   ┆ 10/31/2013 ┆ null      ┆ NYPD   ┆ … ┆ null      ┆ 40.721041 ┆ -73.90945 ┆ (40.72104 │
# │            ┆ 02:01:04   ┆           ┆        ┆   ┆           ┆           ┆ 3         ┆ 053562830 │
# │            ┆ AM         ┆           ┆        ┆   ┆           ┆           ┆           ┆ 5, -73.90 │
# │            ┆            ┆           ┆        ┆   ┆           ┆           ┆           ┆ 94530…    │
# │ 26594139   ┆ 10/31/2013 ┆ 10/31/201 ┆ NYPD   ┆ … ┆ null      ┆ 40.84333  ┆ -73.93914 ┆ (40.84332 │
# │            ┆ 02:00:24   ┆ 3         ┆        ┆   ┆           ┆           ┆ 4         ┆ 975466513 │
# │            ┆ AM         ┆ 02:40:32  ┆        ┆   ┆           ┆           ┆           ┆ , -73.939 │
# │            ┆            ┆ AM        ┆        ┆   ┆           ┆           ┆           ┆ 14371…    │
# │ 26595721   ┆ 10/31/2013 ┆ 10/31/201 ┆ NYPD   ┆ … ┆ null      ┆ 40.778009 ┆ -73.98021 ┆ (40.77800 │
# │            ┆ 01:56:23   ┆ 3         ┆        ┆   ┆           ┆           ┆ 3         ┆ 87446372, │
# │            ┆ AM         ┆ 02:21:48  ┆        ┆   ┆           ┆           ┆           ┆ -73.98021 │
# │            ┆            ┆ AM        ┆        ┆   ┆           ┆           ┆           ┆ 3490…     │
# │ 26590930   ┆ 10/31/2013 ┆ null      ┆ DOHMH  ┆ … ┆ null      ┆ 40.807691 ┆ -73.94738 ┆ (40.80769 │
# │            ┆ 01:53:44   ┆           ┆        ┆   ┆           ┆           ┆ 7         ┆ 092704951 │
# │            ┆ AM         ┆           ┆        ┆   ┆           ┆           ┆           ┆ , -73.947 │
# │            ┆            ┆           ┆        ┆   ┆           ┆           ┆           ┆ 38703…    │
# └────────────┴────────────┴───────────┴────────┴───┴───────────┴───────────┴───────────┴───────────┘
# OrderedDict([('Unique Key', Int64),
#              ('Created Date', Utf8),
#              ('Closed Date', Utf8),
#              ('Agency', Utf8),
#              ('Agency Name', Utf8),
#              ('Complaint Type', Utf8),
#              ('Descriptor', Utf8),
#              ('Location Type', Utf8),
#              ('Incident Zip', Utf8),
#              ('Incident Address', Utf8),
#              ('Street Name', Utf8),
#              ('Cross Street 1', Utf8),
#              ('Cross Street 2', Utf8),
#              ('Intersection Street 1', Utf8),
#              ('Intersection Street 2', Utf8),
#              ('Address Type', Utf8),
#              ('City', Utf8),
#              ('Landmark', Utf8),
#              ('Facility Type', Utf8),
#              ('Status', Utf8),
#              ('Due Date', Utf8),
#              ('Resolution Action Updated Date', Utf8),
#              ('Community Board', Utf8),
#              ('Borough', Utf8),
#              ('X Coordinate (State Plane)', Int64),
#              ('Y Coordinate (State Plane)', Int64),
#              ('Park Facility Name', Utf8),
#              ('Park Borough', Utf8),
#              ('School Name', Utf8),
#              ('School Number', Utf8),
#              ('School Region', Utf8),
#              ('School Code', Utf8),
#              ('School Phone Number', Utf8),
#              ('School Address', Utf8),
#              ('School City', Utf8),
#              ('School State', Utf8),
#              ('School Zip', Utf8),
#              ('School Not Found', Utf8),
#              ('School or Citywide Complaint', Utf8),
#              ('Vehicle Type', Utf8),
#              ('Taxi Company Borough', Utf8),
#              ('Taxi Pick Up Location', Utf8),
#              ('Bridge Highway Name', Utf8),
#              ('Bridge Highway Direction', Utf8),
#              ('Road Ramp', Utf8),
#              ('Bridge Highway Segment', Utf8),
#              ('Garage Lot Name', Utf8),
#              ('Ferry Direction', Utf8),
#              ('Ferry Terminal Name', Utf8),
#              ('Latitude', Float64),
#              ('Longitude', Float64),
#              ('Location', Utf8)])

# %% [markdown]
# # 7.1 How do we know if it's messy?

# %% [markdown]
# We're going to look at a few columns here. I know already that there are some problems with the zip code, so let's look at that first.
#
# To get a sense for whether a column has problems, I usually use `.unique()` to look at all its values. If it's a numeric column, I'll instead plot a histogram to get a sense of the distribution.
#
# When we look at the unique values in "Incident Zip", it quickly becomes clear that this is a mess.
#
# Some of the problems:
#
# * Some have been parsed as strings, and some as floats
# * There are `nan`s
# * Some of the zip codes are `29616-0759` or `83`
# * There are some N/A values that polars didn't recognize, like 'N/A' and 'NO CLUE'
#
# What we can do:
#
# * Normalize 'N/A' and 'NO CLUE' into regular nan values
# * Look at what's up with the 83, and decide what to do
# * Make everything strings

# %%
requests['Incident Zip'].unique().sort()
# Out:
# shape: (251,)
# Series: 'Incident Zip' [str]
# [
# 	null
# 	"00000"
# 	"000000"
# 	"00083"
# 	"02061"
# 	"06901"
# 	"07020"
# 	"07087"
# 	"07093"
# 	"07109"
# 	"07114"
# 	"07201"
# 	…
# 	"29616-0759"
# 	"35209-3114"
# 	"41042"
# 	"55164-0737"
# 	"61702"
# 	"70711"
# 	"77056"
# 	"77092-2016"
# 	"90010"
# 	"92123"
# 	"N/A"
# 	"NA"
# 	"NO CLUE"
# ]

# %% [markdown]
# # 7.2 Fixing the null_values and string/float confusion

# %% [markdown]
# We can pass a `null_values` option to `pl.read_csv` to clean this up a little bit. We can also specify that the type of Incident Zip is a string, not a float.

# %%
null_values = ['NO CLUE', 'N/A', '0', 'NA']
requests = pl.read_csv(path, null_values=null_values, dtypes={'Incident Zip':pl.Utf8})
requests['Incident Zip'].unique().sort()
# Out:
# shape: (248,)
# Series: 'Incident Zip' [str]
# [
# 	null
# 	"00000"
# 	"000000"
# 	"00083"
# 	"02061"
# 	"06901"
# 	"07020"
# 	"07087"
# 	"07093"
# 	"07109"
# 	"07114"
# 	"07201"
# 	…
# 	"19711"
# 	"23502"
# 	"23541"
# 	"29616-0759"
# 	"35209-3114"
# 	"41042"
# 	"55164-0737"
# 	"61702"
# 	"70711"
# 	"77056"
# 	"77092-2016"
# 	"90010"
# 	"92123"
# ]

# %% [markdown]
# # 7.3 What's up with the dashes?

# %%
rows_with_dashes = requests.filter(
                            pl.col('Incident Zip').str.contains('-')
                            )

print('number of zip codes with dashes: ', rows_with_dashes.height)
rows_with_dashes.head()
# Out:
# number of zip codes with dashes:  5
# shape: (5, 52)
# ┌────────────┬────────────┬────────────┬────────┬───┬────────────┬──────────┬───────────┬──────────┐
# │ Unique Key ┆ Created    ┆ Closed     ┆ Agency ┆ … ┆ Ferry      ┆ Latitude ┆ Longitude ┆ Location │
# │ ---        ┆ Date       ┆ Date       ┆ ---    ┆   ┆ Terminal   ┆ ---      ┆ ---       ┆ ---      │
# │ i64        ┆ ---        ┆ ---        ┆ str    ┆   ┆ Name       ┆ f64      ┆ f64       ┆ str      │
# │            ┆ str        ┆ str        ┆        ┆   ┆ ---        ┆          ┆           ┆          │
# │            ┆            ┆            ┆        ┆   ┆ str        ┆          ┆           ┆          │
# ╞════════════╪════════════╪════════════╪════════╪═══╪════════════╪══════════╪═══════════╪══════════╡
# │ 26550551   ┆ 10/24/2013 ┆ null       ┆ DCA    ┆ … ┆ null       ┆ null     ┆ null      ┆ null     │
# │            ┆ 06:16:34   ┆            ┆        ┆   ┆            ┆          ┆           ┆          │
# │            ┆ PM         ┆            ┆        ┆   ┆            ┆          ┆           ┆          │
# │ 26548831   ┆ 10/24/2013 ┆ null       ┆ DCA    ┆ … ┆ null       ┆ null     ┆ null      ┆ null     │
# │            ┆ 09:35:10   ┆            ┆        ┆   ┆            ┆          ┆           ┆          │
# │            ┆ AM         ┆            ┆        ┆   ┆            ┆          ┆           ┆          │
# │ 26488417   ┆ 10/15/2013 ┆ null       ┆ TLC    ┆ … ┆ null       ┆ null     ┆ null      ┆ null     │
# │            ┆ 03:40:33   ┆            ┆        ┆   ┆            ┆          ┆           ┆          │
# │            ┆ PM         ┆            ┆        ┆   ┆            ┆          ┆           ┆          │
# │ 26468296   ┆ 10/10/2013 ┆ 10/26/2013 ┆ DCA    ┆ … ┆ null       ┆ null     ┆ null      ┆ null     │
# │            ┆ 12:36:43   ┆ 01:07:07   ┆        ┆   ┆            ┆          ┆           ┆          │
# │            ┆ PM         ┆ AM         ┆        ┆   ┆            ┆          ┆           ┆          │
# │ 26461137   ┆ 10/09/2013 ┆ 10/25/2013 ┆ DCA    ┆ … ┆ null       ┆ null     ┆ null      ┆ null     │
# │            ┆ 05:23:46   ┆ 01:06:41   ┆        ┆   ┆            ┆          ┆           ┆          │
# │            ┆ PM         ┆ AM         ┆        ┆   ┆            ┆          ┆           ┆          │
# └────────────┴────────────┴────────────┴────────┴───┴────────────┴──────────┴───────────┴──────────┘

# %% [markdown]
# I thought these were missing data and originally deleted them. But then my friend Dave pointed out that 9-digit zip codes are normal. Let's look at all the zip codes with more than 5 digits, make sure they're okay, and then truncate them.

# %%
requests.filter(
                pl.col('Incident Zip').str.contains('-')
                )['Incident Zip'].unique()
# Out:
# shape: (5,)
# Series: 'Incident Zip' [str]
# [
# 	"55164-0737"
# 	"77092-2016"
# 	"11549-3650"
# 	"29616-0759"
# 	"35209-3114"
# ]

# %% [markdown]
# Those all look okay to truncate to me.

# %%
requests = requests.with_columns(
                    pl.col('Incident Zip').str.slice(0, 5)
                    )
requests.filter(
                pl.col('Incident Zip').str.contains('-')
                )['Incident Zip'].unique()
# Out:
# shape: (0,)
# Series: 'Incident Zip' [str]
# [
# ]

# %% [markdown]
# Done.

# %% [markdown]
# Earlier I thought 00083 was a broken zip code, but turns out Central Park's zip code 00083! Shows what I know. I'm still concerned about the 00000 zip codes, though: let's look at that.

# %%
requests.filter(
                pl.col('Incident Zip') == '00000'
                )
# Out:
# shape: (2, 52)
# ┌────────────┬──────────────┬────────┬────────┬───┬──────────┬──────────┬───────────┬──────────┐
# │ Unique Key ┆ Created Date ┆ Closed ┆ Agency ┆ … ┆ Ferry    ┆ Latitude ┆ Longitude ┆ Location │
# │ ---        ┆ ---          ┆ Date   ┆ ---    ┆   ┆ Terminal ┆ ---      ┆ ---       ┆ ---      │
# │ i64        ┆ str          ┆ ---    ┆ str    ┆   ┆ Name     ┆ f64      ┆ f64       ┆ str      │
# │            ┆              ┆ str    ┆        ┆   ┆ ---      ┆          ┆           ┆          │
# │            ┆              ┆        ┆        ┆   ┆ str      ┆          ┆           ┆          │
# ╞════════════╪══════════════╪════════╪════════╪═══╪══════════╪══════════╪═══════════╪══════════╡
# │ 26529313   ┆ 10/22/2013   ┆ null   ┆ TLC    ┆ … ┆ null     ┆ null     ┆ null      ┆ null     │
# │            ┆ 02:51:06 PM  ┆        ┆        ┆   ┆          ┆          ┆           ┆          │
# │ 26507389   ┆ 10/17/2013   ┆ null   ┆ TLC    ┆ … ┆ null     ┆ null     ┆ null      ┆ null     │
# │            ┆ 05:48:44 PM  ┆        ┆        ┆   ┆          ┆          ┆           ┆          │
# └────────────┴──────────────┴────────┴────────┴───┴──────────┴──────────┴───────────┴──────────┘

# %% [markdown]
# This looks bad to me. Let's set these to nan.

# %%
requests = requests.with_columns(
                                pl.col('Incident Zip').replace({'00000': None}, default=pl.first())
                                )
requests.filter(pl.col('Incident Zip') == '00000').height
# Out:
# ---------------------------------------------------------------------------
# ComputeError                              Traceback (most recent call last)
# <ipython-input-14-eeebd030e355> in <cell line: 4>()
#       2                                 pl.col('Incident Zip').replace({'00000': None}, default=pl.first())
#       3                                 )
# ----> 4 requests.filter(pl.col('Incident Zip') == '00000').height
#
# /usr/local/lib/python3.10/dist-packages/polars/dataframe/frame.py in filter(self, *predicates, **constraints)
#    4190
#    4191         """
# -> 4192         return self.lazy().filter(*predicates, **constraints).collect(_eager=True)
#    4193
#    4194     @overload
#
# /usr/local/lib/python3.10/dist-packages/polars/lazyframe/frame.py in collect(self, type_coercion, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, no_optimization, streaming, _eager)
#    1704             _eager,
#    1705         )
# -> 1706         return wrap_df(ldf.collect())
#    1707
#    1708     @overload
#
# ComputeError: cannot compare utf-8 with numeric data

# %% [markdown]
# Great. Let's see where we are now:

# %%
unique_zips = requests['Incident Zip'].unique().sort()
unique_zips
# Out:
# shape: (111_068,)
# Series: 'Incident Zip' [i64]
# [
# 	null
# 	26425880
# 	26425882
# 	26425971
# 	26426013
# 	26426026
# 	26426060
# 	26426069
# 	26426094
# 	26426096
# 	26426115
# 	26426116
# 	…
# 	26596119
# 	26596120
# 	26596123
# 	26596124
# 	26596125
# 	26596126
# 	26596127
# 	26596128
# 	26596129
# 	26596130
# 	26596131
# 	26596132
# 	26596133
# ]

# %% [markdown]
# Amazing! This is much cleaner. There's something a bit weird here, though -- I looked up 77056 on Google maps, and that's in Texas.
#
# Let's take a closer look:

# %%
is_close = pl.col('Incident Zip').str.starts_with('0') | pl.col('Incident Zip').str.starts_with('1')
requests.lazy().select(
                        'Incident Zip',
                        'Descriptor',
                        'City'
                        ).filter(~is_close & pl.col('Incident Zip').is_not_null())\
                .sort('Incident Zip').collect()
# Out:
# shape: (111_067, 3)
# ┌──────────────┬──────────────────────┬──────────┐
# │ Incident Zip ┆ Descriptor           ┆ City     │
# │ ---          ┆ ---                  ┆ ---      │
# │ i64          ┆ str                  ┆ str      │
# ╞══════════════╪══════════════════════╪══════════╡
# │ 26425880     ┆ Loud Music/Party     ┆ NEW YORK │
# │ 26425882     ┆ Partial Access       ┆ WOODSIDE │
# │ 26425971     ┆ Loud Talking         ┆ BRONX    │
# │ 26426013     ┆ Structure - Outdoors ┆ BROOKLYN │
# │ …            ┆ …                    ┆ …        │
# │ 26596130     ┆ ELECTRIC-SUPPLY      ┆ BRONX    │
# │ 26596131     ┆ HEAT                 ┆ BRONX    │
# │ 26596132     ┆ WATER-LEAKS          ┆ BROOKLYN │
# │ 26596133     ┆ ELECTRIC-SUPPLY      ┆ BRONX    │
# └──────────────┴──────────────────────┴──────────┘

# %% [markdown]
# Okay, there really are requests coming from LA and Houston! Good to know. Filtering by zip code is probably a bad way to handle this -- we should really be looking at the city instead.

# %%
requests['City'].str.to_uppercase().value_counts(sort=True)
# Out:
# shape: (101, 2)
# ┌────────────────┬───────┐
# │ City           ┆ count │
# │ ---            ┆ ---   │
# │ str            ┆ u32   │
# ╞════════════════╪═══════╡
# │ BROOKLYN       ┆ 31662 │
# │ NEW YORK       ┆ 22664 │
# │ BRONX          ┆ 18438 │
# │ null           ┆ 12215 │
# │ …              ┆ …     │
# │ NANUET         ┆ 1     │
# │ FARMINGDALE    ┆ 1     │
# │ NEW YOR        ┆ 1     │
# │ NEWARK AIRPORT ┆ 1     │
# └────────────────┴───────┘

# %% [markdown]
# There are 12,215 `null` values in the `City` column. Upon closer look, it seems that many of these rows also have missing `Incident Zip` values as well:

# %%
requests.select(
                'Incident Zip',
                'Descriptor',
                'City'
                ).filter(
                        pl.col('City').is_null()
                ).sort('Incident Zip')
# Out:
# shape: (12_215, 3)
# ┌──────────────┬───────────────────────────────────┬──────┐
# │ Incident Zip ┆ Descriptor                        ┆ City │
# │ ---          ┆ ---                               ┆ ---  │
# │ i64          ┆ str                               ┆ str  │
# ╞══════════════╪═══════════════════════════════════╪══════╡
# │ 26427822     ┆ Property Tax Exemption Applicati… ┆ null │
# │ 26433416     ┆ Property Tax Exemption Applicati… ┆ null │
# │ 26433422     ┆ Property Tax Exemption Applicati… ┆ null │
# │ 26433423     ┆ Property Tax Exemption Applicati… ┆ null │
# │ …            ┆ …                                 ┆ …    │
# │ 26596039     ┆ Property Tax Exemption Applicati… ┆ null │
# │ 26596043     ┆ Fallen Debris from Bridge         ┆ null │
# │ 26596067     ┆ 15 Street Cond/Dump-Out/Drop-Off  ┆ null │
# │ 26596119     ┆ Property Tax Exemption Applicati… ┆ null │
# └──────────────┴───────────────────────────────────┴──────┘

# %% [markdown]
# # 7.4 Putting it together

# %% [markdown]
# Here's what we ended up doing to clean up our zip codes, all together:

# %%
null_values = ['NO CLUE', 'N/A', '0', 'NA']
requests = pl.scan_csv(path, null_values=null_values, dtypes={'Incident Zip':pl.Utf8})
requests = (requests
            .with_columns(
                pl.col('Incident Zip').str.slice(0, 5).replace({'00000': None}, default=pl.first())
            ).filter(
                pl.col('Incident Zip').is_not_null()
            ).collect())

# %%
requests['Incident Zip'].unique().sort()
# Out:
# shape: (111_067,)
# Series: 'Incident Zip' [i64]
# [
# 	26425880
# 	26425882
# 	26425971
# 	26426013
# 	26426026
# 	26426060
# 	26426069
# 	26426094
# 	26426096
# 	26426115
# 	26426116
# 	26426164
# 	…
# 	26596119
# 	26596120
# 	26596123
# 	26596124
# 	26596125
# 	26596126
# 	26596127
# 	26596128
# 	26596129
# 	26596130
# 	26596131
# 	26596132
# 	26596133
# ]

# %% [markdown]
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
#     }
#     div.cell{
#         width:800px;
#         margin-left:16% !important;
#         margin-right:auto;
#     }
#     h1 {
#         font-family: Helvetica, serif;
#     }
#     h4{
#         margin-top:12px;
#         margin-bottom: 3px;
#        }
#     div.text_cell_render{
#         font-family: Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 145%;
#         font-size: 130%;
#         width:800px;
#         margin-left:auto;
#         margin-right:auto;
#     }
#     .CodeMirror{
#             font-family: "Source Code Pro", source-code-pro,Consolas, monospace;
#     }
#     .text_cell_render h5 {
#         font-weight: 300;
#         font-size: 22pt;
#         color: #4057A1;
#         font-style: italic;
#         margin-bottom: .5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#
#     .warning{
#         color: rgb( 240, 20, 20 )
#         }
