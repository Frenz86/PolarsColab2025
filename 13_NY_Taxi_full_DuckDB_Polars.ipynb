# %% [markdown]
# # NYC Taxi full dataset ~40 GB - BigData with DuckDB and Polars

# %%
#https://github.com/gerardrbentley/uber-nyc-pickups-duckdb/blob/main/01_duck_streamlit.py

# %%
# !pip install boto3 -q

# %%
import time
import boto3
import os
from botocore import UNSIGNED
from botocore.client import Config
from botocore.exceptions import ResponseStreamingError

s3 = boto3.resource("s3", config=Config(signature_version=UNSIGNED))


def download_s3_folder(bucket_name, s3_folder, local_dir=None):
    bucket = s3.Bucket(bucket_name)
    for obj in bucket.objects.filter(Prefix=s3_folder):
        target = (
            obj.key
            if local_dir is None
            else os.path.join(local_dir, os.path.relpath(obj.key, s3_folder))
        )
        if os.path.exists(target):
            print(f"skipping {target}")
            continue
        if not os.path.exists(os.path.dirname(target)):
            os.makedirs(os.path.dirname(target))
        if obj.key[-1] == "/":
            continue
        print(f"downloading {target}")
        try:
            bucket.download_file(obj.key, target)
        except ResponseStreamingError:
            time.sleep(60)
            bucket.download_file(obj.key, target)
        print(f"downloaded {target}")

if __name__ == '__main__':
    print("BEGIN DOWNLOAD!")
    download_s3_folder("ursa-labs-taxi-data", "", "nyc-taxi")
    print("DONE DOWNLOAD!!!")
# Out:
# BEGIN DOWNLOAD!
# downloading nyc-taxi/2009/01/data.parquet
# downloaded nyc-taxi/2009/01/data.parquet
# downloading nyc-taxi/2009/02/data.parquet
# downloaded nyc-taxi/2009/02/data.parquet
# downloading nyc-taxi/2009/03/data.parquet
# downloaded nyc-taxi/2009/03/data.parquet
# downloading nyc-taxi/2009/04/data.parquet
# downloaded nyc-taxi/2009/04/data.parquet
# downloading nyc-taxi/2009/05/data.parquet
# downloaded nyc-taxi/2009/05/data.parquet
# downloading nyc-taxi/2009/06/data.parquet
# downloaded nyc-taxi/2009/06/data.parquet
# downloading nyc-taxi/2009/07/data.parquet
# downloaded nyc-taxi/2009/07/data.parquet
# downloading nyc-taxi/2009/08/data.parquet
# downloaded nyc-taxi/2009/08/data.parquet
# downloading nyc-taxi/2009/09/data.parquet
# downloaded nyc-taxi/2009/09/data.parquet
# downloading nyc-taxi/2009/10/data.parquet
# downloaded nyc-taxi/2009/10/data.parquet
# downloading nyc-taxi/2009/11/data.parquet
# downloaded nyc-taxi/2009/11/data.parquet
# downloading nyc-taxi/2009/12/data.parquet
# downloaded nyc-taxi/2009/12/data.parquet
# downloading nyc-taxi/2010/01/data.parquet
# downloaded nyc-taxi/2010/01/data.parquet
# downloading nyc-taxi/2010/02/data.parquet
# downloaded nyc-taxi/2010/02/data.parquet
# downloading nyc-taxi/2010/04/data.parquet
# downloaded nyc-taxi/2010/04/data.parquet
# downloading nyc-taxi/2010/05/data.parquet
# downloaded nyc-taxi/2010/05/data.parquet
# downloading nyc-taxi/2010/06/data.parquet
# downloaded nyc-taxi/2010/06/data.parquet
# downloading nyc-taxi/2010/07/data.parquet
# downloaded nyc-taxi/2010/07/data.parquet
# downloading nyc-taxi/2010/08/data.parquet
# downloaded nyc-taxi/2010/08/data.parquet
# downloading nyc-taxi/2010/09/data.parquet
# downloaded nyc-taxi/2010/09/data.parquet
# downloading nyc-taxi/2010/10/data.parquet
# downloaded nyc-taxi/2010/10/data.parquet
# downloading nyc-taxi/2010/11/data.parquet
# downloaded nyc-taxi/2010/11/data.parquet
# downloading nyc-taxi/2010/12/data.parquet
# downloaded nyc-taxi/2010/12/data.parquet
# downloading nyc-taxi/2011/01/data.parquet
# downloaded nyc-taxi/2011/01/data.parquet
# downloading nyc-taxi/2011/02/data.parquet
# downloaded nyc-taxi/2011/02/data.parquet
# downloading nyc-taxi/2011/03/data.parquet
# downloaded nyc-taxi/2011/03/data.parquet
# downloading nyc-taxi/2011/04/data.parquet
# downloaded nyc-taxi/2011/04/data.parquet
# downloading nyc-taxi/2011/05/data.parquet
# downloaded nyc-taxi/2011/05/data.parquet
# downloading nyc-taxi/2011/06/data.parquet
# downloaded nyc-taxi/2011/06/data.parquet
# downloading nyc-taxi/2011/07/data.parquet
# downloaded nyc-taxi/2011/07/data.parquet
# downloading nyc-taxi/2011/08/data.parquet
# downloaded nyc-taxi/2011/08/data.parquet
# downloading nyc-taxi/2011/09/data.parquet
# downloaded nyc-taxi/2011/09/data.parquet
# downloading nyc-taxi/2011/10/data.parquet
# downloaded nyc-taxi/2011/10/data.parquet
# downloading nyc-taxi/2011/11/data.parquet
# downloaded nyc-taxi/2011/11/data.parquet
# downloading nyc-taxi/2011/12/data.parquet
# downloaded nyc-taxi/2011/12/data.parquet
# downloading nyc-taxi/2012/01/data.parquet
# downloaded nyc-taxi/2012/01/data.parquet
# downloading nyc-taxi/2012/02/data.parquet
# downloaded nyc-taxi/2012/02/data.parquet
# downloading nyc-taxi/2012/03/data.parquet
# downloaded nyc-taxi/2012/03/data.parquet
# downloading nyc-taxi/2012/04/data.parquet
# downloaded nyc-taxi/2012/04/data.parquet
# downloading nyc-taxi/2012/05/data.parquet
# downloaded nyc-taxi/2012/05/data.parquet
# downloading nyc-taxi/2012/06/data.parquet
# downloaded nyc-taxi/2012/06/data.parquet
# downloading nyc-taxi/2012/07/data.parquet
# downloaded nyc-taxi/2012/07/data.parquet
# downloading nyc-taxi/2012/08/data.parquet
# downloaded nyc-taxi/2012/08/data.parquet
# downloading nyc-taxi/2012/09/data.parquet
# downloaded nyc-taxi/2012/09/data.parquet
# downloading nyc-taxi/2012/10/data.parquet
# downloaded nyc-taxi/2012/10/data.parquet
# downloading nyc-taxi/2012/11/data.parquet
# downloaded nyc-taxi/2012/11/data.parquet
# downloading nyc-taxi/2012/12/data.parquet
# downloaded nyc-taxi/2012/12/data.parquet
# downloading nyc-taxi/2013/01/data.parquet
# downloaded nyc-taxi/2013/01/data.parquet
# downloading nyc-taxi/2013/02/data.parquet
# downloaded nyc-taxi/2013/02/data.parquet
# downloading nyc-taxi/2013/03/data.parquet
# downloaded nyc-taxi/2013/03/data.parquet
# downloading nyc-taxi/2013/04/data.parquet
# downloaded nyc-taxi/2013/04/data.parquet
# downloading nyc-taxi/2013/05/data.parquet
# downloaded nyc-taxi/2013/05/data.parquet
# downloading nyc-taxi/2013/06/data.parquet
# downloaded nyc-taxi/2013/06/data.parquet
# downloading nyc-taxi/2013/07/data.parquet
# downloaded nyc-taxi/2013/07/data.parquet
# downloading nyc-taxi/2013/08/data.parquet
# downloaded nyc-taxi/2013/08/data.parquet
# downloading nyc-taxi/2013/09/data.parquet
# downloaded nyc-taxi/2013/09/data.parquet
# downloading nyc-taxi/2013/10/data.parquet
# downloaded nyc-taxi/2013/10/data.parquet
# downloading nyc-taxi/2013/11/data.parquet
# downloaded nyc-taxi/2013/12/data.parquet
# downloading nyc-taxi/2014/01/data.parquet
# downloaded nyc-taxi/2014/01/data.parquet
# downloading nyc-taxi/2014/02/data.parquet
# downloaded nyc-taxi/2014/02/data.parquet
# downloading nyc-taxi/2014/03/data.parquet
# downloaded nyc-taxi/2014/03/data.parquet
# downloading nyc-taxi/2014/04/data.parquet
# downloaded nyc-taxi/2014/04/data.parquet
# downloading nyc-taxi/2014/05/data.parquet
# downloaded nyc-taxi/2014/05/data.parquet
# downloading nyc-taxi/2014/06/data.parquet
# downloaded nyc-taxi/2014/06/data.parquet
# downloading nyc-taxi/2014/07/data.parquet
# downloaded nyc-taxi/2014/07/data.parquet
# downloading nyc-taxi/2014/08/data.parquet
# downloaded nyc-taxi/2014/08/data.parquet
# downloading nyc-taxi/2014/09/data.parquet
# downloaded nyc-taxi/2014/09/data.parquet
# downloading nyc-taxi/2014/10/data.parquet
# downloaded nyc-taxi/2014/10/data.parquet
# downloading nyc-taxi/2014/11/data.parquet
# downloaded nyc-taxi/2014/11/data.parquet
# downloading nyc-taxi/2014/12/data.parquet
# downloaded nyc-taxi/2014/12/data.parquet
# downloading nyc-taxi/2015/01/data.parquet
# downloaded nyc-taxi/2015/01/data.parquet
# downloading nyc-taxi/2015/02/data.parquet
# downloaded nyc-taxi/2015/02/data.parquet
# downloading nyc-taxi/2015/03/data.parquet
# downloaded nyc-taxi/2015/03/data.parquet
# downloading nyc-taxi/2015/04/data.parquet
# downloaded nyc-taxi/2015/04/data.parquet
# downloading nyc-taxi/2015/05/data.parquet
# downloaded nyc-taxi/2015/05/data.parquet
# downloading nyc-taxi/2015/06/data.parquet
# downloaded nyc-taxi/2015/06/data.parquet
# downloading nyc-taxi/2015/07/data.parquet
# downloaded nyc-taxi/2015/07/data.parquet
# downloading nyc-taxi/2015/08/data.parquet
# downloaded nyc-taxi/2015/08/data.parquet
# downloading nyc-taxi/2015/09/data.parquet
# downloaded nyc-taxi/2015/09/data.parquet
# downloading nyc-taxi/2015/10/data.parquet
# downloaded nyc-taxi/2015/10/data.parquet
# downloading nyc-taxi/2015/11/data.parquet
# downloaded nyc-taxi/2015/11/data.parquet
# downloading nyc-taxi/2015/12/data.parquet
# downloaded nyc-taxi/2015/12/data.parquet
# downloading nyc-taxi/2016/01/data.parquet
# downloaded nyc-taxi/2016/01/data.parquet
# downloading nyc-taxi/2016/02/data.parquet
# downloaded nyc-taxi/2016/02/data.parquet
# downloading nyc-taxi/2016/03/data.parquet
# downloaded nyc-taxi/2016/03/data.parquet
# downloading nyc-taxi/2016/04/data.parquet
# downloaded nyc-taxi/2016/04/data.parquet
# downloading nyc-taxi/2016/05/data.parquet
# downloaded nyc-taxi/2016/05/data.parquet
# downloading nyc-taxi/2016/06/data.parquet
# downloaded nyc-taxi/2016/06/data.parquet
# downloading nyc-taxi/2016/07/data.parquet
# downloaded nyc-taxi/2016/07/data.parquet
# downloading nyc-taxi/2016/08/data.parquet
# downloaded nyc-taxi/2016/08/data.parquet
# downloading nyc-taxi/2016/09/data.parquet
# downloaded nyc-taxi/2016/09/data.parquet
# downloading nyc-taxi/2016/10/data.parquet
# downloaded nyc-taxi/2016/10/data.parquet
# downloading nyc-taxi/2016/11/data.parquet
# downloaded nyc-taxi/2016/11/data.parquet
# downloading nyc-taxi/2016/12/data.parquet
# downloaded nyc-taxi/2016/12/data.parquet
# downloading nyc-taxi/2017/01/data.parquet
# downloaded nyc-taxi/2017/01/data.parquet
# downloading nyc-taxi/2017/02/data.parquet
# downloaded nyc-taxi/2017/02/data.parquet
# downloading nyc-taxi/2017/03/data.parquet
# downloaded nyc-taxi/2017/03/data.parquet
# downloading nyc-taxi/2017/04/data.parquet
# downloaded nyc-taxi/2017/04/data.parquet
# downloading nyc-taxi/2017/05/data.parquet
# downloaded nyc-taxi/2017/05/data.parquet
# downloading nyc-taxi/2017/06/data.parquet
# downloaded nyc-taxi/2017/06/data.parquet
# downloading nyc-taxi/2017/07/data.parquet
# downloaded nyc-taxi/2017/07/data.parquet
# downloading nyc-taxi/2017/08/data.parquet
# downloaded nyc-taxi/2017/08/data.parquet
# downloading nyc-taxi/2017/09/data.parquet
# downloaded nyc-taxi/2017/09/data.parquet
# downloading nyc-taxi/2017/10/data.parquet
# downloaded nyc-taxi/2017/10/data.parquet
# downloading nyc-taxi/2017/11/data.parquet
# downloaded nyc-taxi/2017/11/data.parquet
# downloading nyc-taxi/2017/12/data.parquet
# downloaded nyc-taxi/2017/12/data.parquet
# downloading nyc-taxi/2018/01/data.parquet
# downloaded nyc-taxi/2018/01/data.parquet
# downloading nyc-taxi/2018/02/data.parquet
# downloaded nyc-taxi/2018/02/data.parquet
# downloading nyc-taxi/2018/03/data.parquet
# downloaded nyc-taxi/2018/03/data.parquet
# downloading nyc-taxi/2018/04/data.parquet
# downloaded nyc-taxi/2018/04/data.parquet
# downloading nyc-taxi/2018/05/data.parquet
# downloaded nyc-taxi/2018/05/data.parquet
# downloading nyc-taxi/2018/06/data.parquet
# downloaded nyc-taxi/2018/06/data.parquet
# downloading nyc-taxi/2018/07/data.parquet
# downloaded nyc-taxi/2018/07/data.parquet
# downloading nyc-taxi/2018/08/data.parquet
# downloaded nyc-taxi/2018/08/data.parquet
# downloading nyc-taxi/2018/09/data.parquet
# downloaded nyc-taxi/2018/09/data.parquet
# downloading nyc-taxi/2018/10/data.parquet
# downloaded nyc-taxi/2018/10/data.parquet
# downloading nyc-taxi/2018/11/data.parquet
# downloaded nyc-taxi/2018/11/data.parquet
# downloading nyc-taxi/2018/12/data.parquet
# downloaded nyc-taxi/2018/12/data.parquet
# downloading nyc-taxi/2019/01/data.parquet
# downloaded nyc-taxi/2019/01/data.parquet
# downloading nyc-taxi/2019/02/data.parquet
# downloaded nyc-taxi/2019/02/data.parquet
# downloading nyc-taxi/2019/03/data.parquet
# downloaded nyc-taxi/2019/03/data.parquet
# downloading nyc-taxi/2019/04/data.parquet
# downloaded nyc-taxi/2019/04/data.parquet
# downloading nyc-taxi/2019/05/data.parquet
# downloaded nyc-taxi/2019/05/data.parquet
# downloading nyc-taxi/2019/06/data.parquet
# downloaded nyc-taxi/2019/06/data.parquet
# DONE DOWNLOAD!!!

# %%
import duckdb
import pyarrow.dataset as ds

nyc = ds.dataset("nyc-taxi/", partitioning=["year", "month"])

con = duckdb.connect()
query = con.execute("SELECT total_amount FROM nyc")

# Create Record Batch Reader from Query Result.
record_batch_reader = query.fetch_record_batch()

total_rows = 0
while True:
    print('chunk total', total_rows)
    try:
        # Process a single chunk here
        # pyarrow.lib.RecordBatch
        chunk = record_batch_reader.read_next_batch()
        total_rows += len(chunk)
    except StopIteration:
        break
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# chunk total 0
# chunk total 1000000
# chunk total 2000000
# chunk total 3000000
# chunk total 4000000
# chunk total 5000000
# chunk total 6000000
# chunk total 7000000
# chunk total 8000000
# chunk total 9000000
# chunk total 10000000
# chunk total 11000000
# chunk total 12000000
# chunk total 13000000
# chunk total 14000000
# chunk total 15000000
# chunk total 16000000
# chunk total 17000000
# chunk total 18000000
# chunk total 19000000
# chunk total 20000000
# chunk total 21000000
# chunk total 22000000
# chunk total 23000000
# chunk total 24000000
# chunk total 25000000
# chunk total 26000000
# chunk total 27000000
# chunk total 28000000
# chunk total 29000000
# chunk total 30000000
# chunk total 31000000
# chunk total 32000000
# chunk total 33000000
# chunk total 34000000
# chunk total 35000000
# chunk total 36000000
# chunk total 37000000
# chunk total 38000000
# chunk total 39000000
# chunk total 40000000
# chunk total 41000000
# chunk total 42000000
# chunk total 43000000
# chunk total 44000000
# chunk total 45000000
# chunk total 46000000
# chunk total 47000000
# chunk total 48000000
# chunk total 49000000
# chunk total 50000000
# chunk total 51000000
# chunk total 52000000
# chunk total 53000000
# chunk total 54000000
# chunk total 55000000
# chunk total 56000000
# chunk total 57000000
# chunk total 58000000
# chunk total 59000000
# chunk total 60000000
# chunk total 61000000
# chunk total 62000000
# chunk total 63000000
# chunk total 64000000
# chunk total 65000000
# chunk total 66000000
# chunk total 67000000
# chunk total 68000000
# chunk total 69000000
# chunk total 70000000
# chunk total 71000000
# chunk total 72000000
# chunk total 73000000
# chunk total 74000000
# chunk total 75000000
# chunk total 76000000
# chunk total 77000000
# chunk total 78000000
# chunk total 79000000
# chunk total 80000000
# chunk total 81000000
# chunk total 82000000
# chunk total 83000000
# chunk total 84000000
# chunk total 85000000
# chunk total 86000000
# chunk total 87000000
# chunk total 88000000
# chunk total 89000000
# chunk total 90000000
# chunk total 91000000
# chunk total 92000000
# chunk total 93000000
# chunk total 94000000
# chunk total 95000000
# chunk total 96000000
# chunk total 97000000
# chunk total 98000000
# chunk total 99000000
# chunk total 100000000
# chunk total 101000000
# chunk total 102000000
# chunk total 103000000
# chunk total 104000000
# chunk total 105000000
# chunk total 106000000
# chunk total 107000000
# chunk total 108000000
# chunk total 109000000
# chunk total 110000000
# chunk total 111000000
# chunk total 112000000
# chunk total 113000000
# chunk total 114000000
# chunk total 115000000
# chunk total 116000000
# chunk total 117000000
# chunk total 118000000
# chunk total 119000000
# chunk total 120000000
# chunk total 121000000
# chunk total 122000000
# chunk total 123000000
# chunk total 124000000
# chunk total 125000000
# chunk total 126000000
# chunk total 127000000
# chunk total 128000000
# chunk total 129000000
# chunk total 130000000
# chunk total 131000000
# chunk total 132000000
# chunk total 133000000
# chunk total 134000000
# chunk total 135000000
# chunk total 136000000
# chunk total 137000000
# chunk total 138000000
# chunk total 139000000
# chunk total 140000000
# chunk total 141000000
# chunk total 142000000
# chunk total 143000000
# chunk total 144000000
# chunk total 145000000
# chunk total 146000000
# chunk total 147000000
# chunk total 148000000
# chunk total 149000000
# chunk total 150000000
# chunk total 151000000
# chunk total 152000000
# chunk total 153000000
# chunk total 154000000
# chunk total 155000000
# chunk total 156000000
# chunk total 157000000
# chunk total 158000000
# chunk total 159000000
# chunk total 160000000
# chunk total 161000000
# chunk total 162000000
# chunk total 163000000
# chunk total 164000000
# chunk total 165000000
# chunk total 166000000
# chunk total 167000000
# chunk total 168000000
# chunk total 169000000
# chunk total 170000000
# chunk total 171000000
# chunk total 172000000
# chunk total 173000000
# chunk total 174000000
# chunk total 175000000
# chunk total 176000000
# chunk total 177000000
# chunk total 178000000
# chunk total 179000000
# chunk total 180000000
# chunk total 181000000
# chunk total 182000000
# chunk total 183000000
# chunk total 184000000
# chunk total 185000000
# chunk total 186000000
# chunk total 187000000
# chunk total 188000000
# chunk total 189000000
# chunk total 190000000
# chunk total 191000000
# chunk total 192000000
# chunk total 193000000
# chunk total 194000000
# chunk total 195000000
# chunk total 196000000
# chunk total 197000000
# chunk total 198000000
# chunk total 199000000
# chunk total 200000000
# chunk total 201000000
# chunk total 202000000
# chunk total 203000000
# chunk total 204000000
# chunk total 205000000
# chunk total 206000000
# chunk total 207000000
# chunk total 208000000
# chunk total 209000000
# chunk total 210000000
# chunk total 211000000
# chunk total 212000000
# chunk total 213000000
# chunk total 214000000
# chunk total 215000000
# chunk total 216000000
# chunk total 217000000
# chunk total 218000000
# chunk total 219000000
# chunk total 220000000
# chunk total 221000000
# chunk total 222000000
# chunk total 223000000
# chunk total 224000000
# chunk total 225000000
# chunk total 226000000
# chunk total 227000000
# chunk total 228000000
# chunk total 229000000
# chunk total 230000000
# chunk total 231000000
# chunk total 232000000
# chunk total 233000000
# chunk total 234000000
# chunk total 235000000
# chunk total 236000000
# chunk total 237000000
# chunk total 238000000
# chunk total 239000000
# chunk total 240000000
# chunk total 241000000
# chunk total 242000000
# chunk total 243000000
# chunk total 244000000
# chunk total 245000000
# chunk total 246000000
# chunk total 247000000
# chunk total 248000000
# chunk total 249000000
# chunk total 250000000
# chunk total 251000000
# chunk total 252000000
# chunk total 253000000
# chunk total 254000000
# chunk total 255000000
# chunk total 256000000
# chunk total 257000000
# chunk total 258000000
# chunk total 259000000
# chunk total 260000000
# chunk total 261000000
# chunk total 262000000
# chunk total 263000000
# chunk total 264000000
# chunk total 265000000
# chunk total 266000000
# chunk total 267000000
# chunk total 268000000
# chunk total 269000000
# chunk total 270000000
# chunk total 271000000
# chunk total 272000000
# chunk total 273000000
# chunk total 274000000
# chunk total 275000000
# chunk total 276000000
# chunk total 277000000
# chunk total 278000000
# chunk total 279000000
# chunk total 280000000
# chunk total 281000000
# chunk total 282000000
# chunk total 283000000
# chunk total 284000000
# chunk total 285000000
# chunk total 286000000
# chunk total 287000000
# chunk total 288000000
# chunk total 289000000
# chunk total 290000000
# chunk total 291000000
# chunk total 292000000
# chunk total 293000000
# chunk total 294000000
# chunk total 295000000
# chunk total 296000000
# chunk total 297000000
# chunk total 298000000
# chunk total 299000000
# chunk total 300000000
# chunk total 301000000
# chunk total 302000000
# chunk total 303000000
# chunk total 304000000
# chunk total 305000000
# chunk total 306000000
# chunk total 307000000
# chunk total 308000000
# chunk total 309000000
# chunk total 310000000
# chunk total 311000000
# chunk total 312000000
# chunk total 313000000
# chunk total 314000000
# chunk total 315000000
# chunk total 316000000
# chunk total 317000000
# chunk total 318000000
# chunk total 319000000
# chunk total 320000000
# chunk total 321000000
# chunk total 322000000
# chunk total 323000000
# chunk total 324000000
# chunk total 325000000
# chunk total 326000000
# chunk total 327000000
# chunk total 328000000
# chunk total 329000000
# chunk total 330000000
# chunk total 331000000
# chunk total 332000000
# chunk total 333000000
# chunk total 334000000
# chunk total 335000000
# chunk total 336000000
# chunk total 337000000
# chunk total 338000000
# chunk total 339000000
# chunk total 340000000
# chunk total 341000000
# chunk total 342000000
# chunk total 343000000
# chunk total 344000000
# chunk total 345000000
# chunk total 346000000
# chunk total 347000000
# chunk total 348000000
# chunk total 349000000
# chunk total 350000000
# chunk total 351000000
# chunk total 352000000
# chunk total 353000000
# chunk total 354000000
# chunk total 355000000
# chunk total 356000000
# chunk total 357000000
# chunk total 358000000
# chunk total 359000000
# chunk total 360000000
# chunk total 361000000
# chunk total 362000000
# chunk total 363000000
# chunk total 364000000
# chunk total 365000000
# chunk total 366000000
# chunk total 367000000
# chunk total 368000000
# chunk total 369000000
# chunk total 370000000
# chunk total 371000000
# chunk total 372000000
# chunk total 373000000
# chunk total 374000000
# chunk total 375000000
# chunk total 376000000
# chunk total 377000000
# chunk total 378000000
# chunk total 379000000
# chunk total 380000000
# chunk total 381000000
# chunk total 382000000
# chunk total 383000000
# chunk total 384000000
# chunk total 385000000
# chunk total 386000000
# chunk total 387000000
# chunk total 388000000
# chunk total 389000000
# chunk total 390000000
# chunk total 391000000
# chunk total 392000000
# chunk total 393000000
# chunk total 394000000
# chunk total 395000000
# chunk total 396000000
# chunk total 397000000
# chunk total 398000000
# chunk total 399000000
# chunk total 400000000
# chunk total 401000000
# chunk total 402000000
# chunk total 403000000
# chunk total 404000000
# chunk total 405000000
# chunk total 406000000
# chunk total 407000000
# chunk total 408000000
# chunk total 409000000
# chunk total 410000000
# chunk total 411000000
# chunk total 412000000
# chunk total 413000000
# chunk total 414000000
# chunk total 415000000
# chunk total 416000000
# chunk total 417000000
# chunk total 418000000
# chunk total 419000000
# chunk total 420000000
# chunk total 421000000
# chunk total 422000000
# chunk total 423000000
# chunk total 424000000
# chunk total 425000000
# chunk total 426000000
# chunk total 427000000
# chunk total 428000000
# chunk total 429000000
# chunk total 430000000
# chunk total 431000000
# chunk total 432000000
# chunk total 433000000
# chunk total 434000000
# chunk total 435000000
# chunk total 436000000
# chunk total 437000000
# chunk total 438000000
# chunk total 439000000
# chunk total 440000000
# chunk total 441000000
# chunk total 442000000
# chunk total 443000000
# chunk total 444000000
# chunk total 445000000
# chunk total 446000000
# chunk total 447000000
# chunk total 448000000
# chunk total 449000000
# chunk total 450000000
# chunk total 451000000
# chunk total 452000000
# chunk total 453000000
# chunk total 454000000
# chunk total 455000000
# chunk total 456000000
# chunk total 457000000
# chunk total 458000000
# chunk total 459000000
# chunk total 460000000
# chunk total 461000000
# chunk total 462000000
# chunk total 463000000
# chunk total 464000000
# chunk total 465000000
# chunk total 466000000
# chunk total 467000000
# chunk total 468000000
# chunk total 469000000
# chunk total 470000000
# chunk total 471000000
# chunk total 472000000
# chunk total 473000000
# chunk total 474000000
# chunk total 475000000
# chunk total 476000000
# chunk total 477000000
# chunk total 478000000
# chunk total 479000000
# chunk total 480000000
# chunk total 481000000
# chunk total 482000000
# chunk total 483000000
# chunk total 484000000
# chunk total 485000000
# chunk total 486000000
# chunk total 487000000
# chunk total 488000000
# chunk total 489000000
# chunk total 490000000
# chunk total 491000000
# chunk total 492000000
# chunk total 493000000
# chunk total 494000000
# chunk total 495000000
# chunk total 496000000
# chunk total 497000000
# chunk total 498000000
# chunk total 499000000
# chunk total 500000000
# chunk total 501000000
# chunk total 502000000
# chunk total 503000000
# chunk total 504000000
# chunk total 505000000
# chunk total 506000000
# chunk total 507000000
# chunk total 508000000
# chunk total 509000000
# chunk total 510000000
# chunk total 511000000
# chunk total 512000000
# chunk total 513000000
# chunk total 514000000
# chunk total 515000000
# chunk total 516000000
# chunk total 517000000
# chunk total 518000000
# chunk total 519000000
# chunk total 520000000
# chunk total 521000000
# chunk total 522000000
# chunk total 523000000
# chunk total 524000000
# chunk total 525000000
# chunk total 526000000
# chunk total 527000000
# chunk total 528000000
# chunk total 529000000
# chunk total 530000000
# chunk total 531000000
# chunk total 532000000
# chunk total 533000000
# chunk total 534000000
# chunk total 535000000
# chunk total 536000000
# chunk total 537000000
# chunk total 538000000
# chunk total 539000000
# chunk total 540000000
# chunk total 541000000
# chunk total 542000000
# chunk total 543000000
# chunk total 544000000
# chunk total 545000000
# chunk total 546000000
# chunk total 547000000
# chunk total 548000000
# chunk total 549000000
# chunk total 550000000
# chunk total 551000000
# chunk total 552000000
# chunk total 553000000
# chunk total 554000000
# chunk total 555000000
# chunk total 556000000
# chunk total 557000000
# chunk total 558000000
# chunk total 559000000
# chunk total 560000000
# chunk total 561000000
# chunk total 562000000
# chunk total 563000000
# chunk total 564000000
# chunk total 565000000
# chunk total 566000000
# chunk total 567000000
# chunk total 568000000
# chunk total 569000000
# chunk total 570000000
# chunk total 571000000
# chunk total 572000000
# chunk total 573000000
# chunk total 574000000
# chunk total 575000000
# chunk total 576000000
# chunk total 577000000
# chunk total 578000000
# chunk total 579000000
# chunk total 580000000
# chunk total 581000000
# chunk total 582000000
# chunk total 583000000
# chunk total 584000000
# chunk total 585000000
# chunk total 586000000
# chunk total 587000000
# chunk total 588000000
# chunk total 589000000
# chunk total 590000000
# chunk total 591000000
# chunk total 592000000
# chunk total 593000000
# chunk total 594000000
# chunk total 595000000
# chunk total 596000000
# chunk total 597000000
# chunk total 598000000
# chunk total 599000000
# chunk total 600000000
# chunk total 601000000
# chunk total 602000000
# chunk total 603000000
# chunk total 604000000
# chunk total 605000000
# chunk total 606000000
# chunk total 607000000
# chunk total 608000000
# chunk total 609000000
# chunk total 610000000
# chunk total 611000000
# chunk total 612000000
# chunk total 613000000
# chunk total 614000000
# chunk total 615000000
# chunk total 616000000
# chunk total 617000000
# chunk total 618000000
# chunk total 619000000
# chunk total 620000000
# chunk total 621000000
# chunk total 622000000
# chunk total 623000000
# chunk total 624000000
# chunk total 625000000
# chunk total 626000000
# chunk total 627000000
# chunk total 628000000
# chunk total 629000000
# chunk total 630000000
# chunk total 631000000
# chunk total 632000000
# chunk total 633000000
# chunk total 634000000
# chunk total 635000000
# chunk total 636000000
# chunk total 637000000
# chunk total 638000000
# chunk total 639000000
# chunk total 640000000
# chunk total 641000000
# chunk total 642000000
# chunk total 643000000
# chunk total 644000000
# chunk total 645000000
# chunk total 646000000
# chunk total 647000000
# chunk total 648000000
# chunk total 649000000
# chunk total 650000000
# chunk total 651000000
# chunk total 652000000
# chunk total 653000000
# chunk total 654000000
# chunk total 655000000
# chunk total 656000000
# chunk total 657000000
# chunk total 658000000
# chunk total 659000000
# chunk total 660000000
# chunk total 661000000
# chunk total 662000000
# chunk total 663000000
# chunk total 664000000
# chunk total 665000000
# chunk total 666000000
# chunk total 667000000
# chunk total 668000000
# chunk total 669000000
# chunk total 670000000
# chunk total 671000000
# chunk total 672000000
# chunk total 673000000
# chunk total 674000000
# chunk total 675000000
# chunk total 676000000
# chunk total 677000000
# chunk total 678000000
# chunk total 679000000
# chunk total 680000000
# chunk total 681000000
# chunk total 682000000
# chunk total 683000000
# chunk total 684000000
# chunk total 685000000
# chunk total 686000000
# chunk total 687000000
# chunk total 688000000
# chunk total 689000000
# chunk total 690000000
# chunk total 691000000
# chunk total 692000000
# chunk total 693000000
# chunk total 694000000
# chunk total 695000000
# chunk total 696000000
# chunk total 697000000
# chunk total 698000000
# chunk total 699000000
# chunk total 700000000
# chunk total 701000000
# chunk total 702000000
# chunk total 703000000
# chunk total 704000000
# chunk total 705000000
# chunk total 706000000
# chunk total 707000000
# chunk total 708000000
# chunk total 709000000
# chunk total 710000000
# chunk total 711000000
# chunk total 712000000
# chunk total 713000000
# chunk total 714000000
# chunk total 715000000
# chunk total 716000000
# chunk total 717000000
# chunk total 718000000
# chunk total 719000000
# chunk total 720000000
# chunk total 721000000
# chunk total 722000000
# chunk total 723000000
# chunk total 724000000
# chunk total 725000000
# chunk total 726000000
# chunk total 727000000
# chunk total 728000000
# chunk total 729000000
# chunk total 730000000
# chunk total 731000000
# chunk total 732000000
# chunk total 733000000
# chunk total 734000000
# chunk total 735000000
# chunk total 736000000
# chunk total 737000000
# chunk total 738000000
# chunk total 739000000
# chunk total 740000000
# chunk total 741000000
# chunk total 742000000
# chunk total 743000000
# chunk total 744000000
# chunk total 745000000
# chunk total 746000000
# chunk total 747000000
# chunk total 748000000
# chunk total 749000000
# chunk total 750000000
# chunk total 751000000
# chunk total 752000000
# chunk total 753000000
# chunk total 754000000
# chunk total 755000000
# chunk total 756000000
# chunk total 757000000
# chunk total 758000000
# chunk total 759000000
# chunk total 760000000
# chunk total 761000000
# chunk total 762000000
# chunk total 763000000
# chunk total 764000000
# chunk total 765000000
# chunk total 766000000
# chunk total 767000000
# chunk total 768000000
# chunk total 769000000
# chunk total 770000000
# chunk total 771000000
# chunk total 772000000
# chunk total 773000000
# chunk total 774000000
# chunk total 775000000
# chunk total 776000000
# chunk total 777000000
# chunk total 778000000
# chunk total 779000000
# chunk total 780000000
# chunk total 781000000
# chunk total 782000000
# chunk total 783000000
# chunk total 784000000
# chunk total 785000000
# chunk total 786000000
# chunk total 787000000
# chunk total 788000000
# chunk total 789000000
# chunk total 790000000
# chunk total 791000000
# chunk total 792000000
# chunk total 793000000
# chunk total 794000000
# chunk total 795000000
# chunk total 796000000
# chunk total 797000000
# chunk total 798000000
# chunk total 799000000
# chunk total 800000000
# chunk total 801000000
# chunk total 802000000
# chunk total 803000000
# chunk total 804000000
# chunk total 805000000
# chunk total 806000000
# chunk total 807000000
# chunk total 808000000
# chunk total 809000000
# chunk total 810000000
# chunk total 811000000
# chunk total 812000000
# chunk total 813000000
# chunk total 814000000
# chunk total 815000000
# chunk total 816000000
# chunk total 817000000
# chunk total 818000000
# chunk total 819000000
# chunk total 820000000
# chunk total 821000000
# chunk total 822000000
# chunk total 823000000
# chunk total 824000000
# chunk total 825000000
# chunk total 826000000
# chunk total 827000000
# chunk total 828000000
# chunk total 829000000
# chunk total 830000000
# chunk total 831000000
# chunk total 832000000
# chunk total 833000000
# chunk total 834000000
# chunk total 835000000
# chunk total 836000000
# chunk total 837000000
# chunk total 838000000
# chunk total 839000000
# chunk total 840000000
# chunk total 841000000
# chunk total 842000000
# chunk total 843000000
# chunk total 844000000
# chunk total 845000000
# chunk total 846000000
# chunk total 847000000
# chunk total 848000000
# chunk total 849000000
# chunk total 850000000
# chunk total 851000000
# chunk total 852000000
# chunk total 853000000
# chunk total 854000000
# chunk total 855000000
# chunk total 856000000
# chunk total 857000000
# chunk total 858000000
# chunk total 859000000
# chunk total 860000000
# chunk total 861000000
# chunk total 862000000
# chunk total 863000000
# chunk total 864000000
# chunk total 865000000
# chunk total 866000000
# chunk total 867000000
# chunk total 868000000
# chunk total 869000000
# chunk total 870000000
# chunk total 871000000
# chunk total 872000000
# chunk total 873000000
# chunk total 874000000
# chunk total 875000000
# chunk total 876000000
# chunk total 877000000
# chunk total 878000000
# chunk total 879000000
# chunk total 880000000
# chunk total 881000000
# chunk total 882000000
# chunk total 883000000
# chunk total 884000000
# chunk total 885000000
# chunk total 886000000
# chunk total 887000000
# chunk total 888000000
# chunk total 889000000
# chunk total 890000000
# chunk total 891000000
# chunk total 892000000
# chunk total 893000000
# chunk total 894000000
# chunk total 895000000
# chunk total 896000000
# chunk total 897000000
# chunk total 898000000
# chunk total 899000000
# chunk total 900000000
# chunk total 901000000
# chunk total 902000000
# chunk total 903000000
# chunk total 904000000
# chunk total 905000000
# chunk total 906000000
# chunk total 907000000
# chunk total 908000000
# chunk total 909000000
# chunk total 910000000
# chunk total 911000000
# chunk total 912000000
# chunk total 913000000
# chunk total 914000000
# chunk total 915000000
# chunk total 916000000
# chunk total 917000000
# chunk total 918000000
# chunk total 919000000
# chunk total 920000000
# chunk total 921000000
# chunk total 922000000
# chunk total 923000000
# chunk total 924000000
# chunk total 925000000
# chunk total 926000000
# chunk total 927000000
# chunk total 928000000
# chunk total 929000000
# chunk total 930000000
# chunk total 931000000
# chunk total 932000000
# chunk total 933000000
# chunk total 934000000
# chunk total 935000000
# chunk total 936000000
# chunk total 937000000
# chunk total 938000000
# chunk total 939000000
# chunk total 940000000
# chunk total 941000000
# chunk total 942000000
# chunk total 943000000
# chunk total 944000000
# chunk total 945000000
# chunk total 946000000
# chunk total 947000000
# chunk total 948000000
# chunk total 949000000
# chunk total 950000000
# chunk total 951000000
# chunk total 952000000
# chunk total 953000000
# chunk total 954000000
# chunk total 955000000
# chunk total 956000000
# chunk total 957000000
# chunk total 958000000
# chunk total 959000000
# chunk total 960000000
# chunk total 961000000
# chunk total 962000000
# chunk total 963000000
# chunk total 964000000
# chunk total 965000000
# chunk total 966000000
# chunk total 967000000
# chunk total 968000000
# chunk total 969000000
# chunk total 970000000
# chunk total 971000000
# chunk total 972000000
# chunk total 973000000
# chunk total 974000000
# chunk total 975000000
# chunk total 976000000
# chunk total 977000000
# chunk total 978000000
# chunk total 979000000
# chunk total 980000000
# chunk total 981000000
# chunk total 982000000
# chunk total 983000000
# chunk total 984000000
# chunk total 985000000
# chunk total 986000000
# chunk total 987000000
# chunk total 988000000
# chunk total 989000000
# chunk total 990000000
# chunk total 991000000
# chunk total 992000000
# chunk total 993000000
# chunk total 994000000
# chunk total 995000000
# chunk total 996000000
# chunk total 997000000
# chunk total 998000000
# chunk total 999000000
# chunk total 1000000000
# chunk total 1001000000
# chunk total 1002000000
# chunk total 1003000000
# chunk total 1004000000
# chunk total 1005000000
# chunk total 1006000000
# chunk total 1007000000
# chunk total 1008000000
# chunk total 1009000000
# chunk total 1010000000
# chunk total 1011000000
# chunk total 1012000000
# chunk total 1013000000
# chunk total 1014000000
# chunk total 1015000000
# chunk total 1016000000
# chunk total 1017000000
# chunk total 1018000000
# chunk total 1019000000
# chunk total 1020000000
# chunk total 1021000000
# chunk total 1022000000
# chunk total 1023000000
# chunk total 1024000000
# chunk total 1025000000
# chunk total 1026000000
# chunk total 1027000000
# chunk total 1028000000
# chunk total 1029000000
# chunk total 1030000000
# chunk total 1031000000
# chunk total 1032000000
# chunk total 1033000000
# chunk total 1034000000
# chunk total 1035000000
# chunk total 1036000000
# chunk total 1037000000
# chunk total 1038000000
# chunk total 1039000000
# chunk total 1040000000
# chunk total 1041000000
# chunk total 1042000000
# chunk total 1043000000
# chunk total 1044000000
# chunk total 1045000000
# chunk total 1046000000
# chunk total 1047000000
# chunk total 1048000000
# chunk total 1049000000
# chunk total 1050000000
# chunk total 1051000000
# chunk total 1052000000
# chunk total 1053000000
# chunk total 1054000000
# chunk total 1055000000
# chunk total 1056000000
# chunk total 1057000000
# chunk total 1058000000
# chunk total 1059000000
# chunk total 1060000000
# chunk total 1061000000
# chunk total 1062000000
# chunk total 1063000000
# chunk total 1064000000
# chunk total 1065000000
# chunk total 1066000000
# chunk total 1067000000
# chunk total 1068000000
# chunk total 1069000000
# chunk total 1070000000
# chunk total 1071000000
# chunk total 1072000000
# chunk total 1073000000
# chunk total 1074000000
# chunk total 1075000000
# chunk total 1076000000
# chunk total 1077000000
# chunk total 1078000000
# chunk total 1079000000
# chunk total 1080000000
# chunk total 1081000000
# chunk total 1082000000
# chunk total 1083000000
# chunk total 1084000000
# chunk total 1085000000
# chunk total 1086000000
# chunk total 1087000000
# chunk total 1088000000
# chunk total 1089000000
# chunk total 1090000000
# chunk total 1091000000
# chunk total 1092000000
# chunk total 1093000000
# chunk total 1094000000
# chunk total 1095000000
# chunk total 1096000000
# chunk total 1097000000
# chunk total 1098000000
# chunk total 1099000000
# chunk total 1100000000
# chunk total 1101000000
# chunk total 1102000000
# chunk total 1103000000
# chunk total 1104000000
# chunk total 1105000000
# chunk total 1106000000
# chunk total 1107000000
# chunk total 1108000000
# chunk total 1109000000
# chunk total 1110000000
# chunk total 1111000000
# chunk total 1112000000
# chunk total 1113000000
# chunk total 1114000000
# chunk total 1115000000
# chunk total 1116000000
# chunk total 1117000000
# chunk total 1118000000
# chunk total 1119000000
# chunk total 1120000000
# chunk total 1121000000
# chunk total 1122000000
# chunk total 1123000000
# chunk total 1124000000
# chunk total 1125000000
# chunk total 1126000000
# chunk total 1127000000
# chunk total 1128000000
# chunk total 1129000000
# chunk total 1130000000
# chunk total 1131000000
# chunk total 1132000000
# chunk total 1133000000
# chunk total 1134000000
# chunk total 1135000000
# chunk total 1136000000
# chunk total 1137000000
# chunk total 1138000000
# chunk total 1139000000
# chunk total 1140000000
# chunk total 1141000000
# chunk total 1142000000
# chunk total 1143000000
# chunk total 1144000000
# chunk total 1145000000
# chunk total 1146000000
# chunk total 1147000000
# chunk total 1148000000
# chunk total 1149000000
# chunk total 1150000000
# chunk total 1151000000
# chunk total 1152000000
# chunk total 1153000000
# chunk total 1154000000
# chunk total 1155000000
# chunk total 1156000000
# chunk total 1157000000
# chunk total 1158000000
# chunk total 1159000000
# chunk total 1160000000
# chunk total 1161000000
# chunk total 1162000000
# chunk total 1163000000
# chunk total 1164000000
# chunk total 1165000000
# chunk total 1166000000
# chunk total 1167000000
# chunk total 1168000000
# chunk total 1169000000
# chunk total 1170000000
# chunk total 1171000000
# chunk total 1172000000
# chunk total 1173000000
# chunk total 1174000000
# chunk total 1175000000
# chunk total 1176000000
# chunk total 1177000000
# chunk total 1178000000
# chunk total 1179000000
# chunk total 1180000000
# chunk total 1181000000
# chunk total 1182000000
# chunk total 1183000000
# chunk total 1184000000
# chunk total 1185000000
# chunk total 1186000000
# chunk total 1187000000
# chunk total 1188000000
# chunk total 1189000000
# chunk total 1190000000
# chunk total 1191000000
# chunk total 1192000000
# chunk total 1193000000
# chunk total 1194000000
# chunk total 1195000000
# chunk total 1196000000
# chunk total 1197000000
# chunk total 1198000000
# chunk total 1199000000
# chunk total 1200000000
# chunk total 1201000000
# chunk total 1202000000
# chunk total 1203000000
# chunk total 1204000000
# chunk total 1205000000
# chunk total 1206000000
# chunk total 1207000000
# chunk total 1208000000
# chunk total 1209000000
# chunk total 1210000000
# chunk total 1211000000
# chunk total 1212000000
# chunk total 1213000000
# chunk total 1214000000
# chunk total 1215000000
# chunk total 1216000000
# chunk total 1217000000
# chunk total 1218000000
# chunk total 1219000000
# chunk total 1220000000
# chunk total 1221000000
# chunk total 1222000000
# chunk total 1223000000
# chunk total 1224000000
# chunk total 1225000000
# chunk total 1226000000
# chunk total 1227000000
# chunk total 1228000000
# chunk total 1229000000
# chunk total 1230000000
# chunk total 1231000000
# chunk total 1232000000
# chunk total 1233000000
# chunk total 1234000000
# chunk total 1235000000
# chunk total 1236000000
# chunk total 1237000000
# chunk total 1238000000
# chunk total 1239000000
# chunk total 1240000000
# chunk total 1241000000
# chunk total 1242000000
# chunk total 1243000000
# chunk total 1244000000
# chunk total 1245000000
# chunk total 1246000000
# chunk total 1247000000
# chunk total 1248000000
# chunk total 1249000000
# chunk total 1250000000
# chunk total 1251000000
# chunk total 1252000000
# chunk total 1253000000
# chunk total 1254000000
# chunk total 1255000000
# chunk total 1256000000
# chunk total 1257000000
# chunk total 1258000000
# chunk total 1259000000
# chunk total 1260000000
# chunk total 1261000000
# chunk total 1262000000
# chunk total 1263000000
# chunk total 1264000000
# chunk total 1265000000
# chunk total 1266000000
# chunk total 1267000000
# chunk total 1268000000
# chunk total 1269000000
# chunk total 1270000000
# chunk total 1271000000
# chunk total 1272000000
# chunk total 1273000000
# chunk total 1274000000
# chunk total 1275000000
# chunk total 1276000000
# chunk total 1277000000
# chunk total 1278000000
# chunk total 1279000000
# chunk total 1280000000
# chunk total 1281000000
# chunk total 1282000000
# chunk total 1283000000
# chunk total 1284000000
# chunk total 1285000000
# chunk total 1286000000
# chunk total 1287000000
# chunk total 1288000000
# chunk total 1289000000
# chunk total 1290000000
# chunk total 1291000000
# chunk total 1292000000
# chunk total 1293000000
# chunk total 1294000000
# chunk total 1295000000
# chunk total 1296000000
# chunk total 1297000000
# chunk total 1298000000
# chunk total 1299000000
# chunk total 1300000000
# chunk total 1301000000
# chunk total 1302000000
# chunk total 1303000000
# chunk total 1304000000
# chunk total 1305000000
# chunk total 1306000000
# chunk total 1307000000
# chunk total 1308000000
# chunk total 1309000000
# chunk total 1310000000
# chunk total 1311000000
# chunk total 1312000000
# chunk total 1313000000
# chunk total 1314000000
# chunk total 1315000000
# chunk total 1316000000
# chunk total 1317000000
# chunk total 1318000000
# chunk total 1319000000
# chunk total 1320000000
# chunk total 1321000000
# chunk total 1322000000
# chunk total 1323000000
# chunk total 1324000000
# chunk total 1325000000
# chunk total 1326000000
# chunk total 1327000000
# chunk total 1328000000
# chunk total 1329000000
# chunk total 1330000000
# chunk total 1331000000
# chunk total 1332000000
# chunk total 1333000000
# chunk total 1334000000
# chunk total 1335000000
# chunk total 1336000000
# chunk total 1337000000
# chunk total 1338000000
# chunk total 1339000000
# chunk total 1340000000
# chunk total 1341000000
# chunk total 1342000000
# chunk total 1343000000
# chunk total 1344000000
# chunk total 1345000000
# chunk total 1346000000
# chunk total 1347000000
# chunk total 1348000000
# chunk total 1349000000
# chunk total 1350000000
# chunk total 1351000000
# chunk total 1352000000
# chunk total 1353000000
# chunk total 1354000000
# chunk total 1355000000
# chunk total 1356000000
# chunk total 1357000000
# chunk total 1358000000
# chunk total 1359000000
# chunk total 1360000000
# chunk total 1361000000
# chunk total 1362000000
# chunk total 1363000000
# chunk total 1364000000
# chunk total 1365000000
# chunk total 1366000000
# chunk total 1367000000
# chunk total 1368000000
# chunk total 1369000000
# chunk total 1370000000
# chunk total 1371000000
# chunk total 1372000000
# chunk total 1373000000
# chunk total 1374000000
# chunk total 1375000000
# chunk total 1376000000
# chunk total 1377000000
# chunk total 1378000000
# chunk total 1379000000
# chunk total 1380000000
# chunk total 1381000000
# chunk total 1382000000
# chunk total 1383000000
# chunk total 1384000000
# chunk total 1385000000
# chunk total 1386000000
# chunk total 1387000000
# chunk total 1388000000
# chunk total 1389000000
# chunk total 1390000000
# chunk total 1391000000
# chunk total 1392000000
# chunk total 1393000000
# chunk total 1394000000
# chunk total 1395000000
# chunk total 1396000000
# chunk total 1397000000
# chunk total 1398000000
# chunk total 1399000000
# chunk total 1400000000
# chunk total 1401000000
# chunk total 1402000000
# chunk total 1403000000
# chunk total 1404000000
# chunk total 1405000000
# chunk total 1406000000
# chunk total 1407000000
# chunk total 1408000000
# chunk total 1409000000
# chunk total 1410000000
# chunk total 1411000000
# chunk total 1412000000
# chunk total 1413000000
# chunk total 1414000000
# chunk total 1415000000
# chunk total 1416000000
# chunk total 1417000000
# chunk total 1418000000
# chunk total 1419000000
# chunk total 1420000000
# chunk total 1421000000
# chunk total 1422000000
# chunk total 1423000000
# chunk total 1424000000
# chunk total 1425000000
# chunk total 1426000000
# chunk total 1427000000
# chunk total 1428000000
# chunk total 1429000000
# chunk total 1430000000
# chunk total 1431000000
# chunk total 1432000000
# chunk total 1433000000
# chunk total 1434000000
# chunk total 1435000000
# chunk total 1436000000
# chunk total 1437000000
# chunk total 1438000000
# chunk total 1439000000
# chunk total 1440000000
# chunk total 1441000000
# chunk total 1442000000
# chunk total 1443000000
# chunk total 1444000000
# chunk total 1445000000
# chunk total 1446000000
# chunk total 1447000000
# chunk total 1448000000
# chunk total 1449000000
# chunk total 1450000000
# chunk total 1451000000
# chunk total 1452000000
# chunk total 1453000000
# chunk total 1454000000
# chunk total 1455000000
# chunk total 1456000000
# chunk total 1457000000
# chunk total 1458000000
# chunk total 1459000000
# chunk total 1460000000
# chunk total 1461000000
# chunk total 1462000000
# chunk total 1463000000
# chunk total 1464000000
# chunk total 1465000000
# chunk total 1466000000
# chunk total 1467000000
# chunk total 1468000000
# chunk total 1469000000
# chunk total 1470000000
# chunk total 1471000000
# chunk total 1472000000
# chunk total 1473000000
# chunk total 1474000000
# chunk total 1475000000
# chunk total 1476000000
# chunk total 1477000000
# chunk total 1478000000
# chunk total 1479000000
# chunk total 1480000000
# chunk total 1481000000
# chunk total 1482000000
# chunk total 1483000000
# chunk total 1484000000
# chunk total 1485000000
# chunk total 1486000000
# chunk total 1487000000
# chunk total 1488000000
# chunk total 1489000000
# chunk total 1490000000
# chunk total 1491000000
# chunk total 1492000000
# chunk total 1493000000
# chunk total 1494000000
# chunk total 1495000000
# chunk total 1496000000
# chunk total 1497000000
# chunk total 1498000000
# chunk total 1499000000
# chunk total 1500000000
# chunk total 1501000000
# chunk total 1502000000
# chunk total 1503000000
# chunk total 1504000000
# chunk total 1505000000
# chunk total 1506000000
# chunk total 1507000000
# chunk total 1508000000
# chunk total 1509000000
# chunk total 1510000000
# chunk total 1511000000
# chunk total 1512000000
# chunk total 1513000000
# chunk total 1514000000
# chunk total 1515000000
# chunk total 1516000000
# chunk total 1517000000
# chunk total 1518000000
# chunk total 1519000000
# chunk total 1520000000
# chunk total 1521000000
# chunk total 1522000000
# chunk total 1523000000
# chunk total 1524000000
# chunk total 1525000000
# chunk total 1526000000
# chunk total 1527000000
# chunk total 1528000000
# chunk total 1529000000
# chunk total 1530000000
# chunk total 1531000000
# chunk total 1532000000
# chunk total 1533000000
# chunk total 1534000000
# chunk total 1535000000
# chunk total 1536000000
# chunk total 1537000000
# chunk total 1538000000
# chunk total 1539000000
# chunk total 1540000000
# chunk total 1541000000
# chunk total 1542000000
# chunk total 1543000000
# chunk total 1544000000
# chunk total 1545000000
# chunk total 1546000000
# chunk total 1547000000
# chunk total 1547741381

# %% [markdown]
# ## NYC Taxi with DuckDB and polars

# %%
import duckdb
import pyarrow as pa
import pyarrow.dataset as ds
import polars as pl
from time import perf_counter as timer

def analyze_nyc_taxi(min_year=2014, min_amount=100):
    """
    Analyze NYC taxi data with specified filters using Polars LazyFrame
    """
    print("Starting analysis...")
    start_time = timer()

    # Open dataset using year,month folder partition
    nyc = ds.dataset("nyc-taxi/", partitioning=["year", "month"])

    # Get database connection
    con = duckdb.connect()
    query= f"""
        SELECT
            total_amount,
            passenger_count,
            year,
            pickup_at,
            pickup_longitude as lon,
            pickup_latitude as lat
        FROM nyc
        WHERE total_amount > {min_amount}
            AND year >= {min_year}
            AND lat is not null
            AND lon is not null
    """
    req = con.execute(query)

    # Create Record Batch Reader and convert to Polars
    record_batch_reader = req.fetch_record_batch()

    # Process chunks and convert to Polars LazyFrame
    all_chunks = []
    total_rows = 0

    while True:
        try:
            chunk = record_batch_reader.read_next_batch()
            # Convert PyArrow RecordBatch to Polars DataFrame
            pl_chunk = pl.from_arrow(pa.Table.from_batches([chunk]))
            all_chunks.append(pl_chunk)
            total_rows += len(pl_chunk)
            print(f"Processed chunk, total rows: {total_rows}")
        except StopIteration:
            break

    end_time = timer()
    runtime = end_time - start_time

    # Combine all chunks into a single Polars DataFrame
    df = pl.concat(all_chunks)
    # Create a LazyFrame for further processing
    lf = df.lazy()

    print(f"\nAnalysis completed in {runtime:.2f} seconds")
    print(f"Total rows processed: {total_rows}")

    return lf, runtime

def get_summary_stats(lf):
    """Calculate statistics total_amount using LazyFrame operations"""
    stats = (
        lf.select([
            pl.col("total_amount").mean().alias("avg_fare"),
            pl.col("total_amount").min().alias("min_fare"),
            pl.col("total_amount").max().alias("max_fare"),
            pl.col("passenger_count").mean().alias("avg_passengers"),
            pl.col("year").value_counts().alias("trips_by_year")
        ])
    ).collect()

    return stats

# %%
# %%time

lf, runtime = analyze_nyc_taxi(min_year=2009, min_amount=35) #3.5 min with min_year=2009, min_amount=35
# Out:
# Starting analysis...
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Processed chunk, total rows: 1000000
# Processed chunk, total rows: 2000000
# Processed chunk, total rows: 3000000
# Processed chunk, total rows: 4000000
# Processed chunk, total rows: 5000000
# Processed chunk, total rows: 6000000
# Processed chunk, total rows: 7000000
# Processed chunk, total rows: 8000000
# Processed chunk, total rows: 9000000
# Processed chunk, total rows: 10000000
# Processed chunk, total rows: 11000000
# Processed chunk, total rows: 12000000
# Processed chunk, total rows: 13000000
# Processed chunk, total rows: 14000000
# Processed chunk, total rows: 15000000
# Processed chunk, total rows: 16000000
# Processed chunk, total rows: 17000000
# Processed chunk, total rows: 18000000
# Processed chunk, total rows: 19000000
# Processed chunk, total rows: 20000000
# Processed chunk, total rows: 21000000
# Processed chunk, total rows: 22000000
# Processed chunk, total rows: 23000000
# Processed chunk, total rows: 24000000
# Processed chunk, total rows: 25000000
# Processed chunk, total rows: 26000000
# Processed chunk, total rows: 27000000
# Processed chunk, total rows: 28000000
# Processed chunk, total rows: 29000000
# Processed chunk, total rows: 30000000
# Processed chunk, total rows: 31000000
# Processed chunk, total rows: 32000000
# Processed chunk, total rows: 33000000
# Processed chunk, total rows: 34000000
# Processed chunk, total rows: 35000000
# Processed chunk, total rows: 36000000
# Processed chunk, total rows: 37000000
# Processed chunk, total rows: 38000000
# Processed chunk, total rows: 39000000
# Processed chunk, total rows: 40000000
# Processed chunk, total rows: 41000000
# Processed chunk, total rows: 42000000
# Processed chunk, total rows: 43000000
# Processed chunk, total rows: 44000000
# Processed chunk, total rows: 45000000
# Processed chunk, total rows: 46000000
# Processed chunk, total rows: 47000000
# Processed chunk, total rows: 48000000
# Processed chunk, total rows: 49000000
# Processed chunk, total rows: 50000000
# Processed chunk, total rows: 51000000
# Processed chunk, total rows: 52000000
# Processed chunk, total rows: 53000000
# Processed chunk, total rows: 54000000
# Processed chunk, total rows: 55000000
# Processed chunk, total rows: 56000000
# Processed chunk, total rows: 57000000
# Processed chunk, total rows: 58000000
# Processed chunk, total rows: 59000000
# Processed chunk, total rows: 60000000
# Processed chunk, total rows: 61000000
# Processed chunk, total rows: 62000000
# Processed chunk, total rows: 63000000
# Processed chunk, total rows: 63477143
#
# Analysis completed in 231.54 seconds
# Total rows processed: 63477143
# CPU times: user 2min 20s, sys: 37.8 s, total: 2min 58s
# Wall time: 3min 51s

# %%
lf
# Out:
# <h4>NAIVE QUERY PLAN</h4><p>run <b>LazyFrame.show_graph()</b> to see the optimized version</p><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: polars_query Pages: 1 -->
# <svg width="67pt" height="61pt"
#  viewBox="0.00 0.00 67.00 61.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 57)">
# <title>polars_query</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-57 63,-57 63,4 -4,4"/>
# <!-- p1 -->
# <g id="node1" class="node">
# <title>p1</title>
# <polygon fill="none" stroke="black" points="59,-53 0,-53 0,0 59,0 59,-53"/>
# <text text-anchor="middle" x="29.5" y="-37.8" font-family="Times,serif" font-size="14.00">TABLE</text>
# <text text-anchor="middle" x="29.5" y="-22.8" font-family="Times,serif" font-size="14.00">π */6;</text>
# <text text-anchor="middle" x="29.5" y="-7.8" font-family="Times,serif" font-size="14.00">σ None</text>
# </g>
# </g>
# </svg>

# %%
# Convert LazyFrame to regular Polars DataFrame
df = lf.collect()
df
# Out:
# shape: (63_477_143, 6)
# ┌──────────────┬─────────────────┬──────┬─────────────────────┬────────────┬───────────┐
# │ total_amount ┆ passenger_count ┆ year ┆ pickup_at           ┆ lon        ┆ lat       │
# │ ---          ┆ ---             ┆ ---  ┆ ---                 ┆ ---        ┆ ---       │
# │ f32          ┆ i8              ┆ i32  ┆ datetime[μs]        ┆ f32        ┆ f32       │
# ╞══════════════╪═════════════════╪══════╪═════════════════════╪════════════╪═══════════╡
# │ 35.450001    ┆ 1               ┆ 2009 ┆ 2009-01-21 14:38:05 ┆ -73.997314 ┆ 40.736099 │
# │ 38.220001    ┆ 1               ┆ 2009 ┆ 2009-01-06 14:51:53 ┆ -73.862762 ┆ 40.769268 │
# │ 45.0         ┆ 2               ┆ 2009 ┆ 2009-01-03 16:27:10 ┆ -73.984085 ┆ 40.756809 │
# │ 45.0         ┆ 1               ┆ 2009 ┆ 2009-01-03 16:48:23 ┆ -74.006645 ┆ 40.716652 │
# │ 51.75        ┆ 1               ┆ 2009 ┆ 2009-01-07 15:22:59 ┆ -73.998528 ┆ 40.723438 │
# │ …            ┆ …               ┆ …    ┆ …                   ┆ …          ┆ …         │
# │ 58.34        ┆ 1               ┆ 2016 ┆ 2016-06-21 22:08:36 ┆ -73.784401 ┆ 40.648598 │
# │ 36.84        ┆ 1               ┆ 2016 ┆ 2016-06-21 21:50:55 ┆ -73.863342 ┆ 40.769947 │
# │ 36.34        ┆ 1               ┆ 2016 ┆ 2016-06-21 21:50:55 ┆ -73.871033 ┆ 40.773754 │
# │ 73.300003    ┆ 1               ┆ 2016 ┆ 2016-06-21 22:01:39 ┆ -73.783401 ┆ 40.64875  │
# │ 80.800003    ┆ 1               ┆ 2016 ┆ 2016-06-21 22:01:39 ┆ -73.792809 ┆ 40.658192 │
# └──────────────┴─────────────────┴──────┴─────────────────────┴────────────┴───────────┘

# %%
stats = get_summary_stats(lf)
print("Summary Statistics:")
print(stats)
# Out:
# Summary Statistics:
# shape: (8, 5)
# ┌───────────┬───────────┬───────────┬────────────────┬─────────────────┐
# │ avg_fare  ┆ min_fare  ┆ max_fare  ┆ avg_passengers ┆ trips_by_year   │
# │ ---       ┆ ---       ┆ ---       ┆ ---            ┆ ---             │
# │ f32       ┆ f32       ┆ f32       ┆ f64            ┆ struct[2]       │
# ╞═══════════╪═══════════╪═══════════╪════════════════╪═════════════════╡
# │ 51.979137 ┆ 35.009998 ┆ 3950611.5 ┆ 1.727499       ┆ {2009,4980036}  │
# │ 51.979137 ┆ 35.009998 ┆ 3950611.5 ┆ 1.727499       ┆ {2012,8158817}  │
# │ 51.979137 ┆ 35.009998 ┆ 3950611.5 ┆ 1.727499       ┆ {2013,10895158} │
# │ 51.979137 ┆ 35.009998 ┆ 3950611.5 ┆ 1.727499       ┆ {2016,5458275}  │
# │ 51.979137 ┆ 35.009998 ┆ 3950611.5 ┆ 1.727499       ┆ {2014,11332771} │
# │ 51.979137 ┆ 35.009998 ┆ 3950611.5 ┆ 1.727499       ┆ {2011,6534332}  │
# │ 51.979137 ┆ 35.009998 ┆ 3950611.5 ┆ 1.727499       ┆ {2010,4908528}  │
# │ 51.979137 ┆ 35.009998 ┆ 3950611.5 ┆ 1.727499       ┆ {2015,11209226} │
# └───────────┴───────────┴───────────┴────────────────┴─────────────────┘

# %%
# Get average fare by year
yearly_stats = (
    lf.group_by("year")
    .agg([
        pl.col("total_amount").mean().alias("avg_fare"),
        pl.len().alias("trip_count")
    ])
    .sort("year")
    .collect()
)
print("\nYearly Statistics:")
print(yearly_stats)
# Out:
# Yearly Statistics:
# shape: (8, 3)
# ┌──────┬───────────┬────────────┐
# │ year ┆ avg_fare  ┆ trip_count │
# │ ---  ┆ ---       ┆ ---        │
# │ i32  ┆ f64       ┆ u32        │
# ╞══════╪═══════════╪════════════╡
# │ 2009 ┆ 48.593525 ┆ 4980036    │
# │ 2010 ┆ 48.843003 ┆ 4908528    │
# │ 2011 ┆ 49.288672 ┆ 6534332    │
# │ 2012 ┆ 49.862339 ┆ 8158817    │
# │ 2013 ┆ 51.888556 ┆ 10895158   │
# │ 2014 ┆ 52.842987 ┆ 11332771   │
# │ 2015 ┆ 54.677651 ┆ 11209226   │
# │ 2016 ┆ 54.179889 ┆ 5458275    │
# └──────┴───────────┴────────────┘

# %% [markdown]
# ## with Polars secco (2X LENTO RISPETTO DuckDB)

# %%
import polars as pl
import pyarrow.dataset as ds
from time import perf_counter as timer
from pathlib import Path

def create_lazy_dataset(data_path: str) -> pl.LazyFrame:
    """
    Create a LazyFrame from the partitioned dataset
    """
    # Create dataset with partitioning
    nyc = ds.dataset(data_path, partitioning=["year", "month"])

    # Convert to Polars LazyFrame
    return pl.scan_pyarrow_dataset(nyc)

def build_analysis_query(lf: pl.LazyFrame, min_year: int = 2014, min_amount: float = 100) -> pl.LazyFrame:
    """
    Build the main analysis query keeping everything lazy
    """
    return (
        lf.select([
            "total_amount",
            "passenger_count",
            "year",
            "month",
            "pickup_at",
            "pickup_longitude",
            "pickup_latitude"
        ])
        .filter(
            (pl.col("total_amount") > min_amount) &
            (pl.col("year") >= min_year) &
            (pl.col("pickup_latitude").is_not_null()) &
            (pl.col("pickup_longitude").is_not_null())
        )
        .with_columns([
            pl.col("pickup_longitude").alias("lon"),
            pl.col("pickup_latitude").alias("lat")
        ])
    )

def get_basic_stats(lf: pl.LazyFrame) -> pl.LazyFrame:
    """
    Create a LazyFrame for basic statistics
    """
    return (
        lf.select([
            pl.len().alias("total_rows"),
            pl.col("total_amount").mean().alias("avg_fare"),
            pl.col("total_amount").min().alias("min_fare"),
            pl.col("total_amount").max().alias("max_fare"),
            pl.col("passenger_count").mean().alias("avg_passengers"),
        ])
    )

def get_yearly_stats(lf: pl.LazyFrame) -> pl.LazyFrame:
    """
    Create a LazyFrame for yearly statistics
    """
    return (
        lf.group_by("year")
        .agg([
            pl.col("total_amount").mean().alias("avg_fare"),
            pl.len().alias("trip_count"),
            pl.col("total_amount").sum().alias("total_revenue")
        ])
        .sort("year")
    )

def get_monthly_patterns(lf: pl.LazyFrame) -> pl.LazyFrame:
    """
    Create a LazyFrame for monthly patterns
    """
    return (
        lf.group_by(["year", "month"])
        .agg([
            pl.len().alias("trip_count"),
            pl.col("total_amount").mean().alias("avg_fare")
        ])
        .sort(["year", "month"])
    )

def analyze_taxi_data(data_path: str, min_year: int = 2014, min_amount: float = 100):
    """
    Main analysis function that keeps operations lazy until final collection
    """
    print("Starting analysis...")
    start_time = timer()

    # Create base LazyFrame
    base_lf = create_lazy_dataset(data_path)

    # Build main analysis query
    analysis_lf = build_analysis_query(base_lf, min_year, min_amount)

    # Prepare all analysis queries (still lazy)
    basic_stats_lf = get_basic_stats(analysis_lf)
    yearly_stats_lf = get_yearly_stats(analysis_lf)
    monthly_patterns_lf = get_monthly_patterns(analysis_lf)

    # Collect results only when needed
    results = {
                'basic_stats': basic_stats_lf.collect(),
                'yearly_stats': yearly_stats_lf.collect(),
                'monthly_patterns': monthly_patterns_lf.collect(),
                }
    end_time = timer()
    runtime = end_time - start_time

    print(f"\nAnalysis completed in {runtime:.2f} seconds")
    print(f"Total rows processed: {results['basic_stats']['total_rows'][0]}")

    return analysis_lf, results, runtime

# %%
# Run the analysis
# %%time
data_path = "nyc-taxi/"
lf, results, runtime = analyze_taxi_data(data_path=data_path,min_year=2009,min_amount=35) # circa 9 min con min_year=2009,min_amount=35
# Out:
# Starting analysis...
#
# Analysis completed in 530.88 seconds
# Total rows processed: 63477143

# %%
# Print basic statistics
print("\nBasic Statistics:")
print(results['basic_stats'])
# Out:
# Basic Statistics:
# shape: (1, 5)
# ┌────────────┬───────────┬───────────┬───────────┬────────────────┐
# │ total_rows ┆ avg_fare  ┆ min_fare  ┆ max_fare  ┆ avg_passengers │
# │ ---        ┆ ---       ┆ ---       ┆ ---       ┆ ---            │
# │ u32        ┆ f32       ┆ f32       ┆ f32       ┆ f64            │
# ╞════════════╪═══════════╪═══════════╪═══════════╪════════════════╡
# │ 63477143   ┆ 51.979137 ┆ 35.009998 ┆ 3950611.5 ┆ 1.727499       │
# └────────────┴───────────┴───────────┴───────────┴────────────────┘

# %%
# Print yearly statistics
print("\nYearly Statistics:")
print(results['yearly_stats'])
# Out:
# Yearly Statistics:
# shape: (8, 4)
# ┌──────┬───────────┬────────────┬───────────────┐
# │ year ┆ avg_fare  ┆ trip_count ┆ total_revenue │
# │ ---  ┆ ---       ┆ ---        ┆ ---           │
# │ i32  ┆ f64       ┆ u32        ┆ f32           │
# ╞══════╪═══════════╪════════════╪═══════════════╡
# │ 2009 ┆ 48.593525 ┆ 4980036    ┆ 2.41997504e8  │
# │ 2010 ┆ 48.843003 ┆ 4908528    ┆ 2.39747248e8  │
# │ 2011 ┆ 49.288672 ┆ 6534332    ┆ 3.22068544e8  │
# │ 2012 ┆ 49.862339 ┆ 8158817    ┆ 4.06817696e8  │
# │ 2013 ┆ 51.888556 ┆ 10895158   ┆ 5.65334016e8  │
# │ 2014 ┆ 52.842987 ┆ 11332771   ┆ 5.98857472e8  │
# │ 2015 ┆ 54.677651 ┆ 11209226   ┆ 6.12894144e8  │
# │ 2016 ┆ 54.179889 ┆ 5458275    ┆ 2.95728736e8  │
# └──────┴───────────┴────────────┴───────────────┘

# %%
# Print monthly patterns
print("\nMonthly Patterns:")
print(results['monthly_patterns'])
# Out:
# Monthly Patterns:
# shape: (89, 4)
# ┌──────┬───────┬────────────┬───────────┐
# │ year ┆ month ┆ trip_count ┆ avg_fare  │
# │ ---  ┆ ---   ┆ ---        ┆ ---       │
# │ i32  ┆ i32   ┆ u32        ┆ f64       │
# ╞══════╪═══════╪════════════╪═══════════╡
# │ 2009 ┆ 1     ┆ 324094     ┆ 48.835026 │
# │ 2009 ┆ 2     ┆ 318258     ┆ 48.758812 │
# │ 2009 ┆ 3     ┆ 394992     ┆ 48.837511 │
# │ 2009 ┆ 4     ┆ 385753     ┆ 48.78389  │
# │ 2009 ┆ 5     ┆ 425945     ┆ 48.743326 │
# │ …    ┆ …     ┆ …          ┆ …         │
# │ 2016 ┆ 2     ┆ 810478     ┆ 54.23402  │
# │ 2016 ┆ 3     ┆ 940763     ┆ 54.49375  │
# │ 2016 ┆ 4     ┆ 928302     ┆ 53.778141 │
# │ 2016 ┆ 5     ┆ 1019728    ┆ 54.236428 │
# │ 2016 ┆ 6     ┆ 954911     ┆ 56.020123 │
# └──────┴───────┴────────────┴───────────┘

# %%
# Get average fare by year
yearly_stats = (
    lf.group_by("year")
    .agg([
        pl.col("total_amount").mean().alias("avg_fare"),
        pl.len().alias("trip_count")
    ])
    .sort("year")
    .collect()
)
print("\nYearly Statistics:")
print(yearly_stats)
